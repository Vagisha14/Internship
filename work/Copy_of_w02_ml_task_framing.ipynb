# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Vagisha14/Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane as an ML Task
#
# Task Type: Classification
#
# This problem is a classification task because the goal is to predict the correct category for each data record based on its features. The model learns patterns from historical data and assigns each record to the most appropriate class.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Target or Proxy
#
# The target is the class label that the model needs to predict. This label comes from the observed data in the dataset and is used during training. If the actual target is unavailable, a suitable proxy that closely represents the desired outcome can be used.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Success Metric
#
# The success metric is Accuracy, which measures the percentage of correctly classified records. Precision, Recall, and F1-score can also be used to evaluate performance, especially when the dataset is imbalanced.

# %% [markdown]
# ## Success Metric
#
# The success metric is Accuracy, which measures the percentage of correctly classified records. Precision, Recall, and F1-score can also be used to evaluate performance, especially when the dataset is imbalanced.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Unit of Analysis
#
# One row in the dataframe represents one individual observation or record. Each column contains a feature describing that observation, while the target column represents the value that the model predicts.

# %% [markdown]
# ## Unit of Analysis
#
# One row in the dataframe represents one individual observation or record. Each column contains a feature describing that observation, while the target column represents the value that the model predicts.
#
# ## Why ML Beats a Fixed Rule
#
# Machine learning can discover complex relationships and patterns in the data that fixed rules cannot capture. It adapts to new data, improves prediction accuracy, and performs better when the data contains many variables or changing patterns.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Why ML Beats a Fixed Rule
#
# Machine learning can discover complex relationships and patterns in the data that fixed rules cannot capture. It adapts to new data, improves prediction accuracy, and performs better when the data contains many variables or changing patterns.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## Self Check
#
# - ✔ Task type identified.
# - ✔ Target or proxy defined.
# - ✔ Success metric selected.
# - ✔ Unit of analysis shown using a real dataframe.
# - ✔ Explained why machine learning is better than a fixed rule.
