# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Vagisha14/Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because it focuses on identifying website pages that should be updated to improve their performance. Instead of reviewing every page manually, data can help prioritize the pages that are most likely to benefit from a content refresh. This approach saves time, improves decision-making, and makes content optimization more efficient.

# %% [markdown]
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because it focuses on identifying website pages that should be updated to improve their performance. Instead of reviewing every page manually, data can help prioritize the pages that are most likely to benefit from a content refresh. This approach saves time, improves decision-making, and makes content optimization more efficient.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Research Question
#
# **Search Question:** Which web pages should be refreshed first to improve search performance?
#
# **Unit of Analysis:** One web page.
#
# **Output:** A ranked list of pages that should be refreshed.
#
# **Action:** The content team reviews and updates the highest-priority pages first.
#
# **Cost of a Wrong Recommendation:** Time and effort may be wasted on pages that do not improve performance, while more important pages may be ignored.
#
# **Why Data/ML Helps:** Data can analyze thousands of pages quickly, identify useful patterns, and help prioritize content more efficiently than manual review.

# %% [markdown]
# ## Research Question
#
# **Search Question:** Which web pages should be refreshed first to improve search performance?
#
# **Unit of Analysis:** One web page.
#
# **Output:** A ranked list of pages that should be refreshed.
#
# **Action:** The content team reviews and updates the highest-priority pages first.
#
# **Cost of a Wrong Recommendation:** Time and effort may be wasted on pages that do not improve performance, while more important pages may be ignored.
#
# **Why Data/ML Helps:** Data can analyze thousands of pages quickly, identify useful patterns, and help prioritize content more efficiently than manual review.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Quick Look at the Data
#
# The dataset contains **30,000 rows** and **44 columns**. Each row represents a content page with multiple features that can be used to evaluate whether the page should be refreshed. Exploring the dataset helped me understand its structure and the information available before carrying out further analysis.

# %% [markdown]
# ## Quick Look at the Data
#
# The dataset contains **30,000 rows** and **44 columns**. Each row represents a content page with multiple features that can be used to evaluate whether the page should be refreshed. Exploring the dataset helped me understand its structure and the information available before carrying out further analysis.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Careful Words
#
# The recommendations produced from this analysis are intended to support decision-making, not replace human judgment. Before refreshing any page, the content team should review the recommendation and consider additional business context.

# %% [markdown]
# ## Careful Words
#
# The recommendations produced from this analysis are intended to support decision-making, not replace human judgment. Before refreshing any page, the content team should review the recommendation and consider additional business context.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ## Self-Check
#
# - ✅ I selected the Refresh / Content Opportunity Scoring lane.
# - ✅ I defined a clear research question.
# - ✅ I explored the dataset and identified that it contains 30,000 rows and 44 columns.
# - ✅ I explained the action that should be taken based on the analysis.
# - ✅ I described the cost of an incorrect recommendation.

# %% [markdown]
# ## Self-Check
#
# - ✅ I selected the Refresh / Content Opportunity Scoring lane.
# - ✅ I defined a clear research question.
# - ✅ I explored the dataset and identified that it contains 30,000 rows and 44 columns.
# - ✅ I explained the action that should be taken based on the analysis.
# - ✅ I described the cost of an incorrect recommendation.
